# %% [markdown]
# # <b> JPMC Team #1: CSV of Adjusted Closing Prices for S&P 500 </b>

# %% [markdown]
# #### Create CSV of data to not have to continously have to download it

# %%
import pandas as pd
import numpy as np
import os
! pip3 install --quiet yfinance
! pip3 install --quiet pandas_datareader
from datetime import datetime
import yfinance as yf
import pandas_datareader.data as web; yf.pdr_override()
import warnings

# %%
start_date = '2023-03-02'
end_date  = '2023-03-21'

data_dir = 'data'

# %%
data    = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies#S%26P_500_component_stocks')
table_symbol   = data[0]
table_industry = data[0]['GICS Sector']
symbols = list(table_symbol.Symbol.values) ##companies
industries = list(table_industry.values) ##Industry Sector

symbols_industries_dict = {}
symbols_industries = data[0].iloc[:, [0,2]].values.tolist()
for pair in symbols_industries:
  keys, values = pair
  symbols_industries_dict[keys] = values

print("{} symbols in total".format(len(symbols)))
print("{} industries in total".format(len(industries)))
set(industries)
# Out:
# 503 symbols in total
# 503 industries in total
# {'Communication Services',
#  'Consumer Discretionary',
#  'Consumer Staples',
#  'Energy',
#  'Financials',
#  'Health Care',
#  'Industrials',
#  'Information Technology',
#  'Materials',
#  'Real Estate',
#  'Utilities'}

# %%
dates = '_{}--{}'.format(start_date, end_date)
dates
os.makedirs(data_dir, exist_ok=True)

# %%
df_create = pd.DataFrame()
company_names = sorted(symbols)
company_names.remove('BF.B')
company_names.remove('BRK.B')
company_names.remove('KVUE')
company_names.remove('VLTO')

a = len(company_names)

df_create.index = company_names
#days = []
#for i in range(2,22):
    #days.append("Adj Close 3-" + str(i))

#for day in days:
    #df_create[day] = a * ['']
df_create
#BF.B, BRK.B, KVUE, VLTO'
# Out:
# Empty DataFrame
# Columns: []
# Index: [A, AAL, AAPL, ABBV, ABNB, ABT, ACGL, ACN, ADBE, ADI, ADM, ADP, ADSK, AEE, AEP, AES, AFL, AIG, AIZ, AJG, AKAM, ALB, ALGN, ALK, ALL, ALLE, AMAT, AMCR, AMD, AME, AMGN, AMP, AMT, AMZN, ANET, ANSS, AON, AOS, APA, APD, APH, APTV, ARE, ATO, ATVI, AVB, AVGO, AVY, AWK, AXON, AXP, AZO, BA, BAC, BALL, BAX, BBWI, BBY, BDX, BEN, BG, BIIB, BIO, BK, BKNG, BKR, BLK, BMY, BR, BRO, BSX, BWA, BX, BXP, C, CAG, CAH, CARR, CAT, CB, CBOE, CBRE, CCI, CCL, CDAY, CDNS, CDW, CE, CEG, CF, CFG, CHD, CHRW, CHTR, CI, CINF, CL, CLX, CMA, CMCSA, ...]
#
# [499 rows x 0 columns]

# %%
for i, symbol in enumerate(symbols):
    try:
        df = web.get_data_yahoo(symbol, start_date, end_date)
        df = df[['Adj Close']]
        
        # Assuming that 'symbol' is the company symbol/ticker, you can use it to add data to 'df_create'
        for day, adj_close in df.iterrows():
            df_create.at[symbol, "Adj Close " + day.strftime("%Y-%m-%d")] = adj_close[0]
            warnings.simplefilter(action='ignore', category=FutureWarning)
            
    except KeyError:
        print("Error for {}".format(symbol))
        pass
#print("Stored {} files".format(i+1))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# /var/folders/bq/q6bbfq_s68l_m1x6yxgvqnt80000gn/T/ipykernel_23282/1429263701.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df_create.at[symbol, "Adj Close " + day.strftime("%Y-%m-%d")] = adj_close[0]
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
df_create
# Out:
#       Adj Close 2023-03-02  Adj Close 2023-03-03  Adj Close 2023-03-06  \
# A               140.885941            143.133423            142.437317
# AAL              16.120001             16.360001             16.120001
# AAPL            145.511963            150.617996            153.410355
# ABBV            149.796082            151.426208            150.669373
# ABNB            122.379997            125.730003            126.330002
# ...                    ...                   ...                   ...
# YUM             127.485062            128.465866            128.099304
# ZBH             122.286400            125.497925            123.907082
# ZBRA            306.059998            309.450012            305.809998
# ZION             46.931580             47.825329             47.368736
# ZTS             167.849579            169.820999            168.934845
#
#       Adj Close 2023-03-07  Adj Close 2023-03-08  Adj Close 2023-03-09  \
# ...

# %%
df_create.isnull().any()
# Out:
# Adj Close 2023-03-02    False
# Adj Close 2023-03-03    False
# Adj Close 2023-03-06    False
# Adj Close 2023-03-07    False
# Adj Close 2023-03-08    False
# Adj Close 2023-03-09    False
# Adj Close 2023-03-10    False
# Adj Close 2023-03-13    False
# Adj Close 2023-03-14    False
# Adj Close 2023-03-15    False
# Adj Close 2023-03-16    False
# Adj Close 2023-03-17    False
# Adj Close 2023-03-20    False
# dtype: bool

# %%
#df_create.to_csv('/Users/annahauk/Desktop/SP500AdjPrice.csv')
#replace with your personal goal destination

# %%
df_create.loc['ABNB']
# Out:
# Adj Close 2023-03-02    122.379997
# Adj Close 2023-03-03    125.730003
# Adj Close 2023-03-06    126.330002
# Adj Close 2023-03-07    126.940002
# Adj Close 2023-03-08    125.000000
# Adj Close 2023-03-09    119.839996
# Adj Close 2023-03-10    118.300003
# Adj Close 2023-03-13    115.959999
# Adj Close 2023-03-14    116.360001
# Adj Close 2023-03-15    113.580002
# Adj Close 2023-03-16    119.989998
# Adj Close 2023-03-17    118.150002
# Adj Close 2023-03-20    118.400002
# Name: ABNB, dtype: float64
